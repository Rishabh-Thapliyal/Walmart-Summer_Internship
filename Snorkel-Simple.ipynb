# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
# import seaborn as sns

from h import *


# %matplotlib inline
sns.set_style("whitegrid")

df= pd.read_csv('/data/DS_INTERN/data/RAW_DATA/train_test_data.csv', low_memory=False)

df1 = add_target_column(df)

train_df , test_df = train_test_split(df1)

train_df = perform_preprocessing(train_df)
test_df = perform_preprocessing(test_df)

# %%
import random
import re

import nltk
from nltk.corpus import wordnet as wn

from snorkel.augmentation import transformation_function

nltk.download("wordnet", quiet=True)

syn_df = pd.read_csv('synonyms_sample.csv', sep=';',header=None, names=['word','synonyms'])


def get_synonyms(word):
    """Get the synonyms of word from Wordnet."""
    
    
    l = ((syn_df[syn_df['word']== word]['synonyms']))
    
    
    if l.shape[0] == 0:
        return []
    else :
        
        l= l.iloc[0]
        
        Syn_List = re.sub("[^\w]", " ",  l).split()

        if len(Syn_List):
            idx = random.choice(range(len(Syn_List)))
            return (Syn_List[idx])


@transformation_function()
def tf_replace_word_with_synonym(x):
    """Try to replace a random word with a synonym."""
    words = [w for w in x['FEAT1'].split()]    
    idx = random.choice(range(len(words)))
  
    synonyms = get_synonyms(words[idx])
    
    if len(synonyms) > 0:
        x['FEAT1'] = " ".join(words[:idx] + [synonyms] + words[idx + 1 :])
    
        return x

# %%
from snorkel.augmentation import ApplyOnePolicy, PandasTFApplier


tf_policy = ApplyOnePolicy(n_per_original=2, keep_original=True)
tf_applier = PandasTFApplier([tf_replace_word_with_synonym], tf_policy)



train_df_augmented = tf_applier.apply(train_df)
# Out:
# 100%|██████████| 48197/48197 [01:51<00:00, 431.14it/s]

# %%
len(train_df_augmented), len(train_df)
# Out:
# (48407, 48197)

# %%
train_df_augmented.head()
# Out:
#                                                 FEAT1  \
# 8   BHF VANILLA CHAI LATTE VANILLA CHAI VANILLA CH...
# 9   ENERGY ACAI BERRY JUICE SAM ENERGY JUICE PREMI...
# 10  GENESIS TODAY POM BERRY POM BERRY GENESIS TODA...
# 11  PEPPERMINT MOCHA BHF PEPMINT MOCHA PEPPERMINT ...
# 12  SAMBAZON ACAI BERRY PACK SAM CAL ACAI JUICE PR...
#
#                        TARGET
# 8   BEVERAGES_BOLTHOUSE JUICE
# 9   BEVERAGES_BOLTHOUSE JUICE
# 10  BEVERAGES_BOLTHOUSE JUICE
# 11  BEVERAGES_BOLTHOUSE JUICE
# 12  BEVERAGES_BOLTHOUSE JUICE

# %%
X_train = train_df_augmented['FEAT1']
Y_train = train_df_augmented['TARGET']

X_test = test_df['FEAT1']

# %%
pipe = pipeline_voting_soft_3(100, kernel='linear')

# %%
pipe
# Out:
# VotingClassifier(estimators=[('RF',
#                               Pipeline(steps=[('vect',
#                                                TfidfVectorizer(min_df=10)),
#                                               ('clf',
#                                                RandomForestClassifier(class_weight='balanced',
#                                                                       n_estimators=220))])),
#                              ('LR',
#                               Pipeline(steps=[('vect',
#                                                TfidfVectorizer(min_df=10)),
#                                               ('clf',
#                                                LogisticRegression(C=250,
#                                                                   class_weight='balanced',
#                                                                   penalty='l1',
#                                                                   solver='saga'))])),
#                              ('SVM',
#                               Pipeline(steps=[('vect',
#                                                TfidfVectorizer(min_df=10)),
#                                               ('clf',
#                                                SVC(class_weight='balanced',
#                                                    kernel='linear'))]))],
#                  voting='soft')

# %%
import time
start = time.time()

pipe.fit(X_train, Y_train)

print('time', time.time() - start, '\n\n')
# Out:
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# time 602.0166957378387

# %%
Y_pred = pipe.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4b21b738b3b4> in <module>()
# ----> 1 Y_pred = pipe.predict(X_test)
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/ensemble/_voting.py in predict(self, X)
#     307         check_is_fitted(self)
#     308         if self.voting == 'soft':
# --> 309             maj = np.argmax(self.predict_proba(X), axis=1)
#     310
#     311         else:  # 'hard' voting
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/ensemble/_voting.py in _predict_proba(self, X)
#     327         """Predict class probabilities for X in 'soft' voting."""
#     328         check_is_fitted(self)
# --> 329         avg = np.average(self._collect_probas(X), axis=0,
#     330                          weights=self._weights_not_none)
#     331         return avg
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/ensemble/_voting.py in _collect_probas(self, X)
#     322     def _collect_probas(self, X):
#     323         """Collect results from clf.predict calls."""
# --> 324         return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#     325
#     326     def _predict_proba(self, X):
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/ensemble/_voting.py in <listcomp>(.0)
#     322     def _collect_probas(self, X):
#     323         """Collect results from clf.predict calls."""
# --> 324         return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#     325
#     326     def _predict_proba(self, X):
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/utils/metaestimators.py in __get__(self, obj, type)
#     112                     continue
#     113                 else:
# --> 114                     getattr(delegate, self.attribute_name)
#     115                     break
#     116             else:
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/svm/_base.py in predict_proba(self)
#     664         datasets.
#     665         """
# --> 666         self._check_proba()
#     667         return self._predict_proba
#     668
#
# ~/libraries/nb_env/lib64/python3.6/site-packages/sklearn/svm/_base.py in _check_proba(self)
#     631     def _check_proba(self):
#     632         if not self.probability:
# --> 633             raise AttributeError("predict_proba is not available when "
#     634                                  " probability=False")
#     635         if self._impl not in ('c_svc', 'nu_svc'):
#
# AttributeError: predict_proba is not available when  probability=False

# %%
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-5943d1bfe3f1> in <module>()
# ----> 1 import xgboost as xgb
#
# /base_env/py3-anaconda-base/lib/python3.6/site-packages/xgboost/__init__.py in <module>()
#       9 import os
#      10
# ---> 11 from .core import DMatrix, Booster
#      12 from .training import train, cv
#      13 from . import rabit                   # noqa
#
# /base_env/py3-anaconda-base/lib/python3.6/site-packages/xgboost/core.py in <module>()
#     113
#     114 # load the XGBoost library globally
# --> 115 _LIB = _load_lib()
#     116
#     117
#
# /base_env/py3-anaconda-base/lib/python3.6/site-packages/xgboost/core.py in _load_lib()
#     107     if len(lib_path) == 0:
#     108         return None
# --> 109     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     110     lib.XGBGetLastError.restype = ctypes.c_char_p
#     111     return lib
#
# /usr/lib64/python3.6/ctypes/__init__.py in LoadLibrary(self, name)
#     419
#     420     def LoadLibrary(self, name):
# --> 421         return self._dlltype(name)
#     422
#     423 cdll = LibraryLoader(CDLL)
#
# /usr/lib64/python3.6/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     341
#     342         if handle is None:
# --> 343             self._handle = _dlopen(self._name, mode)
#     344         else:
#     345             self._handle = handle
#
# OSError: /lib64/libm.so.6: version `GLIBC_2.23' not found (required by /base_env/py3-anaconda-base/lib/python3.6/site-packages/xgboost/libxgboost.so)

# %%
clf = xgb.XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4d0a5e125105> in <module>()
# ----> 1 clf = xgb.XGBClassifier()
#
# NameError: name 'xgb' is not defined

# %%
test_df = trust_factor(Y_pred, test_df)
test_df.describe()

# %%
test_df
# Out:
#                                                     FEAT1 TARGET  \
# 0       TIE ESCAROLE NHM UPC FASTENER TWISTTIE RUBBERB...    NaN
# 1       ODWALLA BERRY MEGA JUICE BRY OMEGA ODW BERRY G...    NaN
# 2       ODWALLA MONSTER NECTAR ODW MONSTER ODWALLA NEC...    NaN
# 3       ODWALLA ORANGE JUICE JUICE ODW JUICE PREMIUM B...    NaN
# 4       RAAW JUICE RASPBERRY LEMONGRASS RAAW RASP LEMN...    NaN
# 5       BERRY WHEATGRASS JUICE JUICE VBW JUICE PREMIUM...    NaN
# 6       ODWALLA CARROT JUICE CARROT ODW CARROT ODW CAR...    NaN
# 7       MANGO GINGER CARROT OZMANGOGINGERCARR JUICE MA...    NaN
# 14      EVOLUTION FRESH ORGANIC STRWBRY LEMONADE ORG J...    NaN
# 15      JUICE ENERGY ODWALLA ODW JUICE ENERGY JUICE PR...    NaN
# 16      SAMBAZON SUPERGREENS KALE GINGE JUICE ACAI SAM...    NaN
# 53      GENESIS TODAY CRANBERRY GOJI JUICE CRANBERRY G...    NaN
# 54      GENESIS TODAY OMEGA ORANGE JUICE OMEGA ORANGE ...    NaN
# 55      GENESIS TODAY POM BERRY GEN ACAI POM JUICE PRE...    NaN
# 56      GENESIS TODAY POM BERRY POM BERRY JUICE JUICE ...    NaN
# 57      GENESIS TODAY POMEGRANATE RESV POM BERRY RESV ...    NaN
# 58      GENESIS TODAY WAKE ENERGY JUICE WAKE JUICE JUI...    NaN
# 59      ORG GTS ROTATIONAL LAVENDER LOVE ORG LAV LOV G...    NaN
# 89      CUCUMBER MINT RECOVERY WATER CUCUMBER MINT JUI...    NaN
# 90      GREEN ELEMENT JUICE JUICE GREEN ELEMENT JUICEO...    NaN
# 91      JUICE BLUEBERRY ACAI JUICE BLEBRY ACI JUICE PR...    NaN
# 92      JUICE PLUM GRAPE BLACKBERRY JUICE PLM GRAPE BL...    NaN
# 93      JUICE RED ELEMENT JUICE RED ELE JUICE PREMIUM ...    NaN
# 94      LEMONGRASS RECOVERY WATER LEMONGRASS JUICE PRE...    NaN
# 95      ORGANIC CAVE CHOCOLATE ORG CHOCOLATE CAVE SHAK...    NaN
# 96      ORGANIC CAVE COFFEE ORG COFFEE CAVE SHAKE PREM...    NaN
# 97      ORGANIC CAVE VANILLA ORG VANILLA CAVE SHAKE PR...    NaN
# 98      ORG DDG GREEN LEMONADE JUICE ORG DDG GREEN ADE...    NaN
# 99      ORIGINAL RECOVERY WATER ORIGNAL RECVRY WATER O...    NaN
# 100     PEACH MANGO JUICE JUICE PEACH MANGO JUICEOLOGY...    NaN
# ...                                                   ...    ...
# 296375  TAIWAN CUT PINE TYWAN CUT PINE CUTPINE CUT FRU...    NaN
# 296376  TAIWAN PINE CUT LARGE TIE ONE CUT PINE DIE TAI...    NaN
# 296377  TAIWAN PINE CUT LARGE TIE ONE CUT PINE DIE TAI...    NaN
# 296378  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296379  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296380  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296381  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296382  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296383  TAIWAN PINE CUT MEDIUM TYWANKAT PINE CHOO TAIW...    NaN
# 296384  CHIKUSHI AGRICULTURAL COOPERATIVE CHIKUSINO GY...    NaN
# 296385  FUJINOSATO FUJINOSATO FUJINOSATO FUJINOSATO FR...    NaN
# 296386  ISHIGURO STORE ISINUKIHIROYAS ISHINUKI HIROYAS...    NaN
# 296387  ISHINUKI RIKIZO SHOTEN FRUIT ISHINUKI LIQUIZOU...    NaN
# 296388  ISHINUKI RIKIZO SHOTEN VEGETABLE ISHINUKI LIQU...    NaN
# 296389  ITOSHIMA GARDEN VEGETABLE VEGETABLE ITOSHIMA N...    NaN
# 296390  MAEHARA AGRICULTURAL HONJO MAEHARANOU SAN HOMP...    NaN
# 296391  MIZUSAKI SHOTEN FRUIT MIZUSAKI SHOTEN MIZUSAKI...    NaN
# 296392  MIZUSAKI SHOTEN VEGETABLE MIZUSAKI SHOTEN MIZU...    NaN
# 296393  OKAMOTO SHOTEN LTD KABUSHIKIGAI SHAOKAMOTO SHO...    NaN
# 296394  SAKAMOTO SHOTEN LTD KABUSHIKIGAISHASASAKAMOTO ...    NaN
# 296395  SATO SHOTEN FRUIT SATOSHOTEN KAJITSU SATO SHOT...    NaN
# 296396  SATO SHOTEN VEGETABLE SATOSHOTEN YASAI SATO SH...    NaN
# 296397  SMALL FARM VEGETABLE EUGENGAISHACHISA NANOOUEN...    NaN
# 296398  SUSHIJI GARDEN VEGETABLE SUSENJI SUSENJI YASAI...    NaN
# 296399  TAKENAMI FRESH MORNING MARKET TAKENAMI FRESH A...    NaN
# 296400  VILLAGE KUSHI HOTARU FIREFLY NOSAT HOTARUNOSAT...    NaN
# 296401  TSUYAZAKI ASAKURO KAI TSUYAZAKI ASATSUYUNOKAI ...    NaN
# 296402  TRAINING TRAINING TRAINING TRAINING FRUIT VEGE...    NaN
# 296403  VND TEST VENDOR TEST VNDTEST VND TESTING FRUIT...    NaN
# 296404  VND TEST VENDOR TEST VNDTEST VND TESTING FRUIT...    NaN
#
#                     category             variety  fuzzy_category  \
# 0                    LETTUCE            ESCAROLE              43
# 1                   BEVERAGE      OTHER BEVERAGE             100
# 2                   BEVERAGE      OTHER BEVERAGE             100
# 3                   BEVERAGE      OTHER BEVERAGE             100
# 4                   BEVERAGE      OTHER BEVERAGE             100
# 5                   BEVERAGE      OTHER BEVERAGE             100
# 6                   BEVERAGE     BOLTHOUSE JUICE             100
# 7                   BEVERAGE      OTHER BEVERAGE             100
# 14                  BEVERAGE     BOLTHOUSE JUICE             100
# 15                  BEVERAGE     BOLTHOUSE JUICE             100
# 16                  BEVERAGE      OTHER BEVERAGE             100
# 53                  BEVERAGE         CLEAN JUICE             100
# 54                  BEVERAGE         CLEAN JUICE             100
# 55                  BEVERAGE         CLEAN JUICE             100
# 56                  BEVERAGE         CLEAN JUICE             100
# 57                  BEVERAGE         CLEAN JUICE             100
# 58                  BEVERAGE         CLEAN JUICE             100
# 59                  BEVERAGE         CLEAN JUICE             100
# 89                  BEVERAGE         CLEAN JUICE             100
# 90                  BEVERAGE         CLEAN JUICE             100
# 91                  BEVERAGE         CLEAN JUICE             100
# 92                  BEVERAGE         CLEAN JUICE             100
# 93                  BEVERAGE         CLEAN JUICE             100
# 94                  BEVERAGE         CLEAN JUICE             100
# 95                  BEVERAGE         CLEAN JUICE             100
# 96                  BEVERAGE         CLEAN JUICE             100
# 97                  BEVERAGE         CLEAN JUICE             100
# 98                  BEVERAGE         CLEAN JUICE             100
# 99                  BEVERAGE         CLEAN JUICE             100
# 100                 BEVERAGE         CLEAN JUICE             100
# ...                      ...                 ...             ...
# 296375   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296376   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296377   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296378   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296379   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296380   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296381   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296382   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296383   CUT FRUIT PROCESSED     PINEAPPLE BLEND             100
# 296384           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296385           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296386           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296387                CITRUS           JACKFRUIT              50
# 296388       MIXED VEGETABLE              RAPINI             100
# 296389       MIXED VEGETABLE              RAPINI             100
# 296390           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296391                CITRUS           JACKFRUIT              50
# 296392       MIXED VEGETABLE              RAPINI             100
# 296393           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296394           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296395                CITRUS           JACKFRUIT              50
# 296396       MIXED VEGETABLE              RAPINI             100
# 296397       MIXED VEGETABLE              RAPINI             100
# 296398       MIXED VEGETABLE              RAPINI             100
# 296399  ETHNIC AND SPECIALTY        PRODUCE WASH              45
# 296400           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296401           DRIED FRUIT  FREEZE DRIED FRUIT             100
# 296402   CUT FRUIT PROCESSED      VEGETABLE TRAY             100
# 296403   CUT FRUIT PROCESSED      VEGETABLE TRAY             100
# 296404   CUT FRUIT PROCESSED      VEGETABLE TRAY             100
#
#         fuzzy_variety  TF_cat  TF_var  TF
# 0                 100       0       1   1
# 1                 100       1       1   1
# 2                 100       1       1   1
# 3                 100       1       1   1
# 4                 100       1       1   1
# 5                 100       1       1   1
# 6                 100       1       1   1
# 7                 100       1       1   1
# 14                100       1       1   1
# 15                100       1       1   1
# 16                100       1       1   1
# 53                100       1       1   1
# 54                100       1       1   1
# 55                100       1       1   1
# 56                100       1       1   1
# 57                 36       1       0   1
# 58                100       1       1   1
# 59                 36       1       0   1
# 89                100       1       1   1
# 90                100       1       1   1
# 91                100       1       1   1
# 92                100       1       1   1
# 93                100       1       1   1
# 94                100       1       1   1
# 95                 45       1       0   1
# 96                 45       1       0   1
# 97                 45       1       0   1
# 98                100       1       1   1
# 99                 36       1       0   1
# 100               100       1       1   1
# ...               ...     ...     ...  ..
# 296375             40       1       0   1
# 296376             53       1       0   1
# 296377             53       1       0   1
# 296378             53       1       0   1
# 296379             53       1       0   1
# 296380             53       1       0   1
# 296381             53       1       0   1
# 296382             53       1       0   1
# 296383             53       1       0   1
# 296384            100       1       1   1
# 296385            100       1       1   1
# 296386            100       1       1   1
# 296387             56       0       0   0
# 296388             50       1       0   1
# 296389             50       1       0   1
# 296390            100       1       1   1
# 296391             56       0       0   0
# 296392             33       1       0   1
# 296393            100       1       1   1
# 296394            100       1       1   1
# 296395             56       0       0   0
# 296396             33       1       0   1
# 296397             33       1       0   1
# 296398             33       1       0   1
# 296399            100       0       1   1
# 296400            100       1       1   1
# 296401            100       1       1   1
# 296402            100       1       1   1
# 296403            100       1       1   1
# 296404            100       1       1   1
#
# [248208 rows x 9 columns]

# %%
pipe1 = pipeline_voting_hard(100)
pipe1.fit(X_train,Y_train)

Y_pred_1 = pipe1.predict(X_test)
# Out:
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
test_df['Predicted_target'] = pd.Series(Y_pred_1, index= test_df.index)
test_df[['category1','variety1']] = test_df['Predicted_target'].str.split('_', expand=True)

# %%
test_df['category1'] = pd.Series(perform_spell_correction_manual(test_df['category1']), index=test_df.index)
test_df['variety1'] = pd.Series(perform_spell_correction_manual(test_df['variety1']), index=test_df.index)

test_df['category1'] = pd.Series(perform_spell_correction_walmart(test_df['category1']), index=test_df.index)
test_df['variety1'] = pd.Series(perform_spell_correction_walmart(test_df['variety1']), index=test_df.index)


test_df['category1'] = pd.Series(perform_lemmatization(test_df['category1']), index=test_df.index)
test_df['variety1'] = pd.Series(perform_lemmatization(test_df['variety1']), index=test_df.index)

# %%
test_df[test_df['variety'] != test_df['variety1']][['variety','variety1','TF_var']].describe()
# Out:
#               TF_var
# count  108828.000000
# mean        0.554076
# std         0.497069
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
pipe = pipeline_voting_hard(100)

# %%
import time
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score, cross_validate

start = time.time()

scores = cross_validate(pipe, X_train, Y_train, scoring= ('accuracy','precision_micro','recall_micro'), cv=5)

print("Accuracy : {:0.5f}".format(scores['test_accuracy'].mean()))
print("Precision_micro : {:0.5f}".format(scores['test_precision_micro'].mean()))
print("Recall_micro : {:0.5f}".format(scores['test_recall_micro'].mean()))


print('time', time.time() - start, '\n\n')
# Out:
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/jupyter/libraries/nb_env/lib64/python3.6/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
